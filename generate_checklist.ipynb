# %%
import pandas as pd
import numpy as np
import os

# %%
all_areas = set()
def process_textfile(file_path: str) -> pd.DataFrame:
    # Create a dictionary to store the data
    data = {"Area": [], "Type": [], "Description": []}

    # Read the text file
    with open(file_path, "r") as f:
        lines = [line.strip() for line in f]
        
    areas = []

    # Iterate through the lines
    for line in lines:
        if line.startswith('In '):
            temp = line[3:].split(": ", 1)
            # Get the Area before the ':'
            area = temp[0].strip()
            # print(f"area: {area}")
            areas.append(area)
            
            # Get Description:
            detail = temp[1].strip()
            # print(f"test description parsing: {detail}")
            data['Area'].append(area)
            data['Type'].append(os.path.splitext(os.path.basename(file_path))[0])
            data['Description'].append(detail)
        elif line.startswith('Excluded'):
            break
        else:
            continue
    # print(f"all areas: {areas}")
    all_areas.update(areas)
    print(f"all areas: {all_areas}")

    # Create a pandas DataFrame from the data dictionary
    df = pd.DataFrame(data)

    # Print the DataFrame
    df.head()
    
    return df

# %%
# List all files in the src folder
all_files = os.listdir()

# Should only have ONE source (src) folder!!!
src_dir = [folder for folder in all_files if folder.startswith('src_')]
if not src_dir:
    raise Exception('No Source Directory found!')
if len(src_dir) > 1:
    raise Exception('Only 1 Source Directory allowed, formatted as "src_..."')
print(src_dir[0])

text_files = [f"{src_dir[0]}/{file}" for file in os.listdir(src_dir[0]) if file.endswith('.txt')]
print(text_files)
# Out:
# src_BP_April_Rando_Any%
# ['src_BP_April_Rando_Any%/Major bosses.txt', 'src_BP_April_Rando_Any%/Merchant shops.txt', 'src_BP_April_Rando_Any%/Shadow Realm Blessing pickups.txt', 'src_BP_April_Rando_Any%/Vanilla major key item locations.txt']

# %%
# Process the text files and combine the resulting DataFrames
dataframes = [process_textfile(file_path) for file_path in text_files]
combined_df = pd.concat(dataframes, ignore_index=True)

# print(combined_df)
combined_df.head()
# Out:
# all areas: {'Academy of Raya Lucaria', 'Stormhill', 'Weeping Peninsula', 'Castle Ensis', 'Mountaintops of the Giants', 'Ainsel River', 'Nokron, Eternal City', 'Stone Platform', 'Caelid', 'Ashen Leyndell', 'Jagged Peak', 'Enir-Ilim', 'Ancient Ruins of Rauh', 'Siofra River', 'Leyndell', 'Scadutree Base', 'Finger Birthing Grounds', 'Stormveil Castle', 'Volcano Manor', 'Specimen Storehouse', 'Farum Azula', 'Mohgwyn', 'Ainsel River Downstream', 'Haligtree', 'Liurnia', "Midra's Manse", 'Scaduview', 'Altus Plateau', 'Shadow Keep', 'Flame Peak', 'Stone Coffin Fissure', 'Subterranean Shunning-Grounds', 'Ruin-Strewn Precipice', 'Belurat'}
# all areas: {'Academy of Raya Lucaria', 'Stormhill', 'Weeping Peninsula', 'Castle Ensis', 'Mountaintops of the Giants', 'Ainsel River', 'Nokron, Eternal City', 'Stone Platform', 'Capital Outskirts', 'Caelid', 'Ashen Leyndell', 'Jagged Peak', 'Enir-Ilim', 'Ancient Ruins of Rauh', 'Siofra River', 'Leyndell', 'Scadutree Base', 'Finger Birthing Grounds', 'Stormveil Castle', 'Volcano Manor', 'Specimen Storehouse', 'Farum Azula', 'Mohgwyn', 'Ainsel River Downstream', 'Haligtree', 'Liurnia Behind Caria Manor', 'Liurnia', "Midra's Manse", 'Scaduview', 'Altus Plateau', 'Shadow Keep', 'Gravesite Plain', 'Flame Peak', 'Mt. Gelmir', 'Stone Coffin Fissure', 'Limgrave - Murkwater Cave', 'Subterranean Shunning-Grounds', 'Ruin-Strewn Precipice', 'Roundtable Hold', 'Belurat', 'Bellum Highway', 'Limgrave', 'Dragonbarrow'}
# all areas: {'Academy of Raya Lucaria', 'Cerulean Coast', 'Lower Scadu Altus', 'Shadow Keep - Church District', 'Stormhill', 'Weeping Peninsula', 'Castle Ensis', 'Mountaintops of the Giants', 'Ainsel River', 'Nokron, Eternal City', 'Stone Platform', 'Capital Outskirts', 'Caelid', 'Ashen Leyndell', 'Ellac River', 'Jagged Peak', 'Enir-Ilim', 'Ancient Ruins of Rauh', 'Siofra River', 'Leyndell', 'Scadutree Base', 'Finger Birthing Grounds', 'Stormveil Castle', 'Volcano Manor', 'Specimen Storehouse', 'Farum Azula', 'Abyssal Woods', 'Mohgwyn', 'Ainsel River Downstream', 'Haligtree', 'Liurnia Behind Caria Manor', 'Liurnia', "Midra's Manse", 'Scaduview', 'Altus Plateau', 'Shadow Keep', 'Gravesite Plain', 'Scadu Altus', 'Flame Peak', 'Mt. Gelmir', 'Stone Coffin Fissure', 'Limgrave - Murkwater Cave', 'Subterranean Shunning-Grounds', 'Ruin-Strewn Precipice', 'Roundtable Hold', 'Belurat', 'Bellum Highway', 'Limgrave', 'Rauh Base', 'Dragonbarrow'}
# all areas: {'Academy of Raya Lucaria', 'Cerulean Coast', 'Lower Scadu Altus', 'Shadow Keep - Church District', 'Stormhill', 'Weeping Peninsula', 'Castle Ensis', 'Mountaintops of the Giants', 'Ainsel River', 'Nokron, Eternal City', 'Stone Platform', 'Capital Outskirts', 'Caelid', 'Ashen Leyndell', 'Ellac River', 'Jagged Peak', 'Enir-Ilim', 'Ancient Ruins of Rauh', 'Siofra River', 'Leyndell', 'Scadutree Base', 'Finger Birthing Grounds', 'Stormveil Castle', 'Volcano Manor', 'Specimen Storehouse', 'Farum Azula', 'Abyssal Woods', 'Mohgwyn', 'Ainsel River Downstream', 'Haligtree', 'Liurnia Behind Caria Manor', 'Liurnia', "Midra's Manse", 'Scaduview', 'Altus Plateau', 'Shadow Keep', 'Gravesite Plain', 'Scadu Altus', 'Flame Peak', 'Mt. Gelmir', 'Stone Coffin Fissure', 'Limgrave - Murkwater Cave', 'Subterranean Shunning-Grounds', 'Ruin-Strewn Precipice', 'Roundtable Hold', 'Belurat', 'Bellum Highway', 'Limgrave', 'Rauh Base', 'Divine Tower of Liurnia', 'Dragonbarrow'}
#                       Area          Type  \
# 0                Stormhill  Major bosses
# 1         Stormveil Castle  Major bosses
# 2        Weeping Peninsula  Major bosses
# 3                  Liurnia  Major bosses
# 4  Academy of Raya Lucaria  Major bosses
#
#                                          Description
# 0  Dropped by Margit the Fell Omen or Morgott the...
# 1  Dropped by Godrick the Grafted. Replaces Godri...
# 2  Dropped by Leonine Misbegotten south of Castle...
# 3  Dropped by Royal Knight Loretta. Replaces Lore...
# 4  Dropped by Red Wolf of Radagon. Replaces Memor...

# %%
combined_df.to_excel("output/combined/combined_data.xlsx", index=False, engine='openpyxl')

# %%
# Sort the combined_df DataFrame by the "Area" column
sorted_df = combined_df.sort_values(by="Area").reset_index(drop=True)

# Print the sorted DataFrame
sorted_df.head()
# Out:
#                       Area                              Type  \
# 0            Abyssal Woods     Shadow Realm Blessing pickups
# 1            Abyssal Woods     Shadow Realm Blessing pickups
# 2  Academy of Raya Lucaria  Vanilla major key item locations
# 3  Academy of Raya Lucaria  Vanilla major key item locations
# 4  Academy of Raya Lucaria                    Merchant shops
#
#                                          Description
# 0  In front of the statue pedestal in Abandoned C...
# 1  On a corpse in front of a tree in the ravine n...
# 2  In a chest unlocked by Discarded Palace Key in...
# 3  On a robed corpse in the Raya Lucaria rooftop ...
# 4  Sold by Isolated Merchant southeast of Main Ac...

# %%
sorted_df.to_excel("output/combined/sorted_data.xlsx", index=False, engine='openpyxl')

# %%
area_keywords = {
    'Limgrave': ['Limgrave', 'Stormhill', 'Knowledge', 'Chapel of Anticipation', 'Stranded Graveyard', 'Beastman', 'Godrick', 'Stormveil', 'Margit', 'Weeping Peninsula', 'Leonine Misbegotten'], 
    'Liurnia of the Lakes': ['Liurnia', 'Academy of Raya Lucaria', 'Makar', 'Bellum', 'Carian', 'Moonlight', 'Red Wolf of Radagon', 'Royal Knight', 'Ruin-Strewn'], 
    'Caelid': ['Redmane', 'Radahn', 'Caelid', 'Dragonbarrow'], 
    'Altus Plateau': ['Altus Plateau', 'Altus Tunnel', 'Capital Outskirts', 'Shaded Castle'], 
    'Mt. Gelmir': ['Mt. Gelmir', 'Volcano Manor', 'Rykard'], 
    'Leyndell, Ashen Capital': ['Ashen'],
    'Leyndell, Royal Capital': ['Royal Capital', 'Leyndell', 'Subterranean Shunning-Grounds', 'Divine Tower of East Altus', 'Divine Tower of West Altus', 'the Omen'],
    'Ainsel River': ['Ainsel', 'Nokstella', 'Dragonkin'],
    'Mountaintops of the Giants': ['Mountaintops', 'Niall', 'Sol', 'Fire Giant', 'Flame Peak', 'Forbidden'],
    'Consecrated Snowfield': ['Consecrated Snowfield'],
    "Miquella's Haligtree": ['Haligtree', 'Malenia'],
    'Crumbling Farum Azula': ['Farum Azula', 'Dragon Temple', 'Godskin Duo', 'Maliketh'],
    'Underground': ['Underground', 'Siofra', 'Ancestor Spirit', 'Nokron', 'Regal', 'Valiant Gargoyles', 'Mimic Tear', 'Lake of Rot', 'Astel, Naturalborn', 'Deeproot Depths'],
    'Moonlight Altar': ['Adula', 'Alecto'],
    'Mohgwyn Dynasty Mausoleum': ['Lord of Blood', 'Mohgwyn'],
    'Roundtable': ['Roundtable'],
    'Gravesite Plain': ['Gravesite Plain', 'Belurat', 'Castle Ensis', "Dragon's Pit", 'Western Nameless', 'Dancing Lion', 'Ellac'],
    'Scadu Altus': ['Scadu Altus', 'Shadow Keep', 'Specimen Storehouse', 'Scaduview', 'Scadutree Base', 'Fort of Reprimand', 'Northern Nameless', 'Birthing', 'Rauh Base'],
    'Hinterlands': ['Hinterlands', 'Manus Metyr'],
    'Cerulean Coast': ['Cerulean Coast', 'Southern Nameless', 'Stone Coffin Fissure'],
    'Jagged Peak': ['Jagged Peak', 'Lamenter'],
    'Abyssal Woods': ['Abyssal Woods', 'Eastern Nameless', 'Darklight', 'Midra' ],
    'Ancient Ruins of Rauh': ['Ancient Ruins of Rauh', 'Bud'],
    'Enir-Ilim': ['Enir-Ilim', 'Consort'],
    'Stone Platform': ['Stone Platform']
}

output_dir = 'output/'

# %%
for key, keywords in area_keywords.items():
    # Iterate over the unique values in the "Area" column and check if they contain any keywords
    areas_to_keep = [area for area in sorted_df["Area"].unique() if any(keyword in area for keyword in keywords)]

    area_keywords[key] = areas_to_keep
    
# print(area_keywords)

for key, areas_to_keep in area_keywords.items():    
    # Filter the sorted_df DataFrame based on the areas_to_keep list
    filtered_df = sorted_df[sorted_df["Area"].isin(areas_to_keep)]
    print(filtered_df.head())
    
    # print(key)
    filtered_df.to_excel(f"{output_dir}{key}.xlsx", index=False, engine='openpyxl')

    # Drop the filtered_df entries from the original sorted_df
    sorted_df = sorted_df.drop(filtered_df.index)

# Print the remaining DataFrame
print(f"\nShould be empty:")
print(sorted_df)
# Out:
#         Area                              Type  \
# 66  Limgrave  Vanilla major key item locations
# 67  Limgrave                    Merchant shops
# 68  Limgrave                    Merchant shops
# 69  Limgrave                    Merchant shops
# 70  Limgrave                    Merchant shops
#
#                                           Description
# 66  In a chest at the top of a tower in Fort Haigh...
# 67  Sold by the Nomadic Merchant in front of Coast...
# 68                Sold by Kale at the Church of Elleh
# 69  Sold by the Nomadic Merchant between Saintsbri...
# 70  Sold by the Nomadic Merchant in the Mistwood a...
#                       Area                              Type  \
# 2  Academy of Raya Lucaria  Vanilla major key item locations
# 3  Academy of Raya Lucaria  Vanilla major key item locations
# 4  Academy of Raya Lucaria                    Merchant shops
# 5  Academy of Raya Lucaria                      Major bosses
# 6  Academy of Raya Lucaria                      Major bosses
#
#                                          Description
# 2  In a chest unlocked by Discarded Palace Key in...
# 3  On a robed corpse in the Raya Lucaria rooftop ...
# 4  Sold by Isolated Merchant southeast of Main Ac...
# 5  Dropped by Red Wolf of Radagon. Replaces Memor...
# 6  Dropped by Rennala. Replaces Great Rune of the...
#             Area                              Type  \
# 24        Caelid  Vanilla major key item locations
# 25        Caelid                    Merchant shops
# 26        Caelid                    Merchant shops
# 27        Caelid                      Major bosses
# 35  Dragonbarrow  Vanilla major key item locations
#
#                                           Description
# 24  In a chest hidden behind a magical barrier in ...
# 25  Sold by the Nomadic Merchant between Astray fr...
# 26  Sold by the Nomadic Merchant southwest of sout...
# 27  Dropped by Starscourge Radahn. Replaces Radahn...
# 35  In a chest up the first ladder at Fort Faroth....
#                  Area            Type  \
# 10      Altus Plateau  Merchant shops
# 11      Altus Plateau    Major bosses
# 28  Capital Outskirts  Merchant shops
#
#                                           Description
# 10  Sold by the Nomadic Merchant at the southern e...
# 11  Dropped by Elemer of the Briar. Replaces Marai...
# 28  Sold by the Hermit Merchant at the Hermit's Me...
#               Area                              Type  \
# 89      Mt. Gelmir                    Merchant shops
# 127  Volcano Manor                      Major bosses
# 128  Volcano Manor                      Major bosses
# 129  Volcano Manor  Vanilla major key item locations
#
#                                            Description
# 89   Sold by the Nomadic Merchant in the long ladde...
# 127  Dropped by Rykard. Replaces Rykard's Great Run...
# 128  Dropped by Godskin Noble. Replaces Godskin Sti...
# 129  Given by Tanith upon joining Volcano Manor, or...
#               Area          Type  \
# 16  Ashen Leyndell  Major bosses
#
#                                           Description
# 16  Dropped by Hoarah Loux. Replaces Remembrance o...
#                               Area                              Type  \
# 63                        Leyndell  Vanilla major key item locations
# 64                        Leyndell                      Major bosses
# 65                        Leyndell                      Major bosses
# 126  Subterranean Shunning-Grounds                      Major bosses
#
#                                            Description
# 63   Given by Melina after defeating Morgott. Repla...
# 64   Dropped by Morgott the Omen King. Replaces Mor...
# 65   Dropped by Godfrey, First Elden Lord, in the E...
# 126  Dropped by Mohg the Omen. Replaces Bloodflame ...
#                       Area            Type  \
# 7             Ainsel River    Major bosses
# 8  Ainsel River Downstream  Merchant shops
# 9  Ainsel River Downstream    Major bosses
#
#                                          Description
# 7  Dropped by Astel, Naturalborn of the Void. Rep...
# 8  Sold by the Hermit Merchant in the alcove past...
# 9  Dropped by Dragonkin Soldier of Nokstella. Rep...
#                           Area                              Type  \
# 49                  Flame Peak                      Major bosses
# 86  Mountaintops of the Giants                      Major bosses
# 87  Mountaintops of the Giants  Vanilla major key item locations
# 88  Mountaintops of the Giants                    Merchant shops
#
#                                           Description
# 49  Dropped by Fire Giant. Replaces Remembrance of...
# 86  Dropped by Commander Niall in Castle Sol. Repl...
# 87  Atop a tower after defeating Commander Niall. ...
# 88  Sold by the Hermit Merchant along a cliffside ...
# Empty DataFrame
# Columns: [Area, Type, Description]
# Index: []
#          Area          Type                                        Description
# 59  Haligtree  Major bosses  Dropped by Malenia. Replaces Malenia's Great R...
# 60  Haligtree  Major bosses  Dropped by Loretta, Knight of the Haligtree. R...
#            Area          Type  \
# 45  Farum Azula  Major bosses
# 46  Farum Azula  Major bosses
# 47  Farum Azula  Major bosses
#
#                                           Description
# 45  Dropped by Maliketh, the Black Blade. Replaces...
# 46  Dropped by Dragonlord Placidusax. Replaces Rem...
# 47  Dropped by Godskin Duo. Replaces Smithing-Ston...
#                      Area            Type  \
# 90   Nokron, Eternal City    Major bosses
# 91   Nokron, Eternal City    Major bosses
# 92   Nokron, Eternal City    Major bosses
# 113          Siofra River    Major bosses
# 114          Siofra River  Merchant shops
#
#                                            Description
# 90   Dropped by Regal Ancestor Spirit. Replaces Rem...
# 91   Dropped by Mimic Tear. Replaces Silver Tear Ma...
# 92   Dropped by Valiant Gargoyles after Siofra Aque...
# 113  Dropped by Ancestor Spirit. Replaces Ancestral...
# 114  Sold by the Abandoned Merchant overlooking the...
# Empty DataFrame
# Columns: [Area, Type, Description]
# Index: []
#        Area            Type                                        Description
# 84  Mohgwyn  Merchant shops  Sold by the Imprisoned Merchant in the cave wi...
# 85  Mohgwyn    Major bosses  Dropped by Mohg, Lord of Blood. Replaces Mohg'...
#                Area            Type                Description
# 94  Roundtable Hold  Merchant shops  Sold by Twin Maiden Husks
#        Area                              Type  \
# 18  Belurat     Shadow Realm Blessing pickups
# 19  Belurat     Shadow Realm Blessing pickups
# 20  Belurat     Shadow Realm Blessing pickups
# 21  Belurat  Vanilla major key item locations
# 22  Belurat                      Major bosses
#
#                                           Description
# 18  By the Miquella's Cross hidden in Belurat, acc...
# 19  On a large withered corpse facing the large tr...
# 20  On a large withered corpse up the elevator fro...
# 21  On a corpse accessible from the bridge above t...
# 22  Dropped by Divine Beast Dancing Lion. Replaces...
#                        Area                           Type  \
# 48  Finger Birthing Grounds                   Major bosses
# 79        Lower Scadu Altus  Shadow Realm Blessing pickups
# 80        Lower Scadu Altus  Shadow Realm Blessing pickups
# 81        Lower Scadu Altus  Shadow Realm Blessing pickups
# 93                Rauh Base  Shadow Realm Blessing pickups
#
#                                           Description
# 48  Dropped by Metyr, Mother of Fingers. Replaces ...
# 79  On a large withered corpse west of the upper V...
# 80  On the large withered corpse in southeast Cast...
# 81  At the bottom of the waterfall below the Reclu...
# 93  On a corpse on a walkway overlooking the block...
# Empty DataFrame
# Columns: [Area, Type, Description]
# Index: []
#                      Area                           Type  \
# 32         Cerulean Coast  Shadow Realm Blessing pickups
# 33         Cerulean Coast  Shadow Realm Blessing pickups
# 120  Stone Coffin Fissure                   Major bosses
# 121  Stone Coffin Fissure  Shadow Realm Blessing pickups
#
#                                            Description
# 32   On a corpse guarded by an enemy in a small cav...
# 33   By Miquella's Cross at the Cerulean Coast Cros...
# 120  Dropped by Putrescent Knight. Replaces Remembr...
# 121  By Miquella's Cross at the Fissure Cross grace...
#            Area                           Type  \
# 61  Jagged Peak                   Major bosses
# 62  Jagged Peak  Shadow Realm Blessing pickups
#
#                                           Description
# 61  Dropped by Bayle the Dread. Replaces Heart of ...
# 62  On a corpse under where the boulder starts rol...
#              Area                           Type  \
# 0   Abyssal Woods  Shadow Realm Blessing pickups
# 1   Abyssal Woods  Shadow Realm Blessing pickups
# 82  Midra's Manse                   Major bosses
# 83  Midra's Manse  Shadow Realm Blessing pickups
#
#                                           Description
# 0   In front of the statue pedestal in Abandoned C...
# 1   On a corpse in front of a tree in the ravine n...
# 82  Dropped by Midra, Lord of Frenzied Flame. Repl...
# 83  On a corpse on a chandelier, accessed by jumpi...
#                      Area                           Type  \
# 12  Ancient Ruins of Rauh  Shadow Realm Blessing pickups
# 13  Ancient Ruins of Rauh                   Major bosses
# 14  Ancient Ruins of Rauh  Shadow Realm Blessing pickups
# 15  Ancient Ruins of Rauh  Shadow Realm Blessing pickups
#
#                                           Description
# 12  On a large withered corpse in the gazebo in th...
# 13  Dropped by Romina, Saint of the Bud. Replaces ...
# 14  By Miquella's Cross at the East Ruins grace. R...
# 15  In front of the northwest wall monument on the...
#          Area                           Type  \
# 38  Enir-Ilim  Shadow Realm Blessing pickups
# 39  Enir-Ilim  Shadow Realm Blessing pickups
# 40  Enir-Ilim                   Major bosses
# 41  Enir-Ilim  Shadow Realm Blessing pickups
# 42  Enir-Ilim  Shadow Realm Blessing pickups
#
#                                           Description
# 38  On a large withered corpse in a shrine after t...
# 39  In front of a statue along the dropdown to Eup...
# 40  Dropped by Promised Consort Radahn. Replaces R...
# 41  On a large withered corpse in front of several...
# 42  In front of the altar in the Cleansing Chamber...
#                Area          Type  \
# 122  Stone Platform  Major bosses
#
#                                            Description
# 122  Dropped by Elden Beast. Replaces Elden Remembr...
#
# Should be empty:
# Empty DataFrame
# Columns: [Area, Type, Description]
# Index: []

# %%
# Combine into one sheet:
