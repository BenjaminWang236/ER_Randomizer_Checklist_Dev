# %%
import pandas as pd
import numpy as np
import os

# %%
all_areas = set()
def process_textfile(file_path: str) -> pd.DataFrame:
    # Create a dictionary to store the data
    data = {"Area": [], "Type": [], "Description": []}

    # Read the text file
    with open(file_path, "r") as f:
        lines = [line.strip() for line in f]
        
    areas = []

    # Iterate through the lines
    for line in lines:
        if line.startswith('In '):
            temp = line[3:].split(": ", 1)
            # Get the Area before the ':'
            area = temp[0].strip()
            # print(f"area: {area}")
            areas.append(area)
            
            # Get Description:
            detail = temp[1].strip()
            # print(f"test description parsing: {detail}")
            data['Area'].append(area)
            data['Type'].append(os.path.splitext(os.path.basename(file_path))[0])
            data['Description'].append(detail)
        elif line.startswith('Excluded'):
            break
        else:
            continue
    # print(f"all areas: {areas}")
    all_areas.update(areas)
    print(f"all areas: {all_areas}")

    # Create a pandas DataFrame from the data dictionary
    df = pd.DataFrame(data)

    # Print the DataFrame
    df.head()
    
    return df

# %%
# List all files in the src folder
all_files = os.listdir()

# Should only have ONE source (src) folder!!!
src_dir = [folder for folder in all_files if folder.startswith('src_')]
if not src_dir:
    raise Exception('No Source Directory found!')
if len(src_dir) > 1:
    raise Exception('Only 1 Source Directory allowed, formatted as "src_..."')
print(src_dir[0])

text_files = [f"{src_dir[0]}/{file}" for file in os.listdir(src_dir[0]) if file.endswith('.txt')]
print(text_files)
# Out:
# src_BP_April_Rando_Any%
# ['src_BP_April_Rando_Any%/Major bosses.txt', 'src_BP_April_Rando_Any%/Merchant shops.txt', 'src_BP_April_Rando_Any%/Shadow Realm Blessing pickups.txt', 'src_BP_April_Rando_Any%/Vanilla major key item locations.txt']

# %%
# Process the text files and combine the resulting DataFrames
dataframes = [process_textfile(file_path) for file_path in text_files]
combined_df = pd.concat(dataframes, ignore_index=True)

# print(combined_df)
combined_df.head()
# Out:
# all areas: {'Academy of Raya Lucaria', 'Stormhill', 'Weeping Peninsula', 'Castle Ensis', 'Mountaintops of the Giants', 'Ainsel River', 'Nokron, Eternal City', 'Stone Platform', 'Caelid', 'Ashen Leyndell', 'Jagged Peak', 'Enir-Ilim', 'Ancient Ruins of Rauh', 'Siofra River', 'Leyndell', 'Scadutree Base', 'Finger Birthing Grounds', 'Stormveil Castle', 'Volcano Manor', 'Specimen Storehouse', 'Farum Azula', 'Mohgwyn', 'Ainsel River Downstream', 'Haligtree', 'Liurnia', "Midra's Manse", 'Scaduview', 'Altus Plateau', 'Shadow Keep', 'Flame Peak', 'Stone Coffin Fissure', 'Subterranean Shunning-Grounds', 'Ruin-Strewn Precipice', 'Belurat'}
# all areas: {'Academy of Raya Lucaria', 'Stormhill', 'Weeping Peninsula', 'Castle Ensis', 'Mountaintops of the Giants', 'Ainsel River', 'Nokron, Eternal City', 'Stone Platform', 'Capital Outskirts', 'Caelid', 'Ashen Leyndell', 'Jagged Peak', 'Enir-Ilim', 'Ancient Ruins of Rauh', 'Siofra River', 'Leyndell', 'Scadutree Base', 'Finger Birthing Grounds', 'Stormveil Castle', 'Volcano Manor', 'Specimen Storehouse', 'Farum Azula', 'Mohgwyn', 'Ainsel River Downstream', 'Haligtree', 'Liurnia Behind Caria Manor', 'Liurnia', "Midra's Manse", 'Scaduview', 'Altus Plateau', 'Shadow Keep', 'Gravesite Plain', 'Flame Peak', 'Mt. Gelmir', 'Stone Coffin Fissure', 'Limgrave - Murkwater Cave', 'Subterranean Shunning-Grounds', 'Ruin-Strewn Precipice', 'Roundtable Hold', 'Belurat', 'Bellum Highway', 'Limgrave', 'Dragonbarrow'}
# all areas: {'Academy of Raya Lucaria', 'Cerulean Coast', 'Lower Scadu Altus', 'Shadow Keep - Church District', 'Stormhill', 'Weeping Peninsula', 'Castle Ensis', 'Mountaintops of the Giants', 'Ainsel River', 'Nokron, Eternal City', 'Stone Platform', 'Capital Outskirts', 'Caelid', 'Ashen Leyndell', 'Ellac River', 'Jagged Peak', 'Enir-Ilim', 'Ancient Ruins of Rauh', 'Siofra River', 'Leyndell', 'Scadutree Base', 'Finger Birthing Grounds', 'Stormveil Castle', 'Volcano Manor', 'Specimen Storehouse', 'Farum Azula', 'Abyssal Woods', 'Mohgwyn', 'Ainsel River Downstream', 'Haligtree', 'Liurnia Behind Caria Manor', 'Liurnia', "Midra's Manse", 'Scaduview', 'Altus Plateau', 'Shadow Keep', 'Gravesite Plain', 'Scadu Altus', 'Flame Peak', 'Mt. Gelmir', 'Stone Coffin Fissure', 'Limgrave - Murkwater Cave', 'Subterranean Shunning-Grounds', 'Ruin-Strewn Precipice', 'Roundtable Hold', 'Belurat', 'Bellum Highway', 'Limgrave', 'Rauh Base', 'Dragonbarrow'}
# all areas: {'Academy of Raya Lucaria', 'Cerulean Coast', 'Lower Scadu Altus', 'Shadow Keep - Church District', 'Stormhill', 'Weeping Peninsula', 'Castle Ensis', 'Mountaintops of the Giants', 'Ainsel River', 'Nokron, Eternal City', 'Stone Platform', 'Capital Outskirts', 'Caelid', 'Ashen Leyndell', 'Ellac River', 'Jagged Peak', 'Enir-Ilim', 'Ancient Ruins of Rauh', 'Siofra River', 'Leyndell', 'Scadutree Base', 'Finger Birthing Grounds', 'Stormveil Castle', 'Volcano Manor', 'Specimen Storehouse', 'Farum Azula', 'Abyssal Woods', 'Mohgwyn', 'Ainsel River Downstream', 'Haligtree', 'Liurnia Behind Caria Manor', 'Liurnia', "Midra's Manse", 'Scaduview', 'Altus Plateau', 'Shadow Keep', 'Gravesite Plain', 'Scadu Altus', 'Flame Peak', 'Mt. Gelmir', 'Stone Coffin Fissure', 'Limgrave - Murkwater Cave', 'Subterranean Shunning-Grounds', 'Ruin-Strewn Precipice', 'Roundtable Hold', 'Belurat', 'Bellum Highway', 'Limgrave', 'Rauh Base', 'Divine Tower of Liurnia', 'Dragonbarrow'}
#                       Area          Type  \
# 0                Stormhill  Major bosses
# 1         Stormveil Castle  Major bosses
# 2        Weeping Peninsula  Major bosses
# 3                  Liurnia  Major bosses
# 4  Academy of Raya Lucaria  Major bosses
#
#                                          Description
# 0  Dropped by Margit the Fell Omen or Morgott the...
# 1  Dropped by Godrick the Grafted. Replaces Godri...
# 2  Dropped by Leonine Misbegotten south of Castle...
# 3  Dropped by Royal Knight Loretta. Replaces Lore...
# 4  Dropped by Red Wolf of Radagon. Replaces Memor...

# %%
combined_df.to_excel("output/combined/combined_data.xlsx", index=False, engine='openpyxl')

# %%
# Sort the combined_df DataFrame by the "Area" column
sorted_df = combined_df.sort_values(by="Area").reset_index(drop=True)

# Print the sorted DataFrame
sorted_df.head()
# Out:
#                       Area                              Type  \
# 0            Abyssal Woods     Shadow Realm Blessing pickups
# 1            Abyssal Woods     Shadow Realm Blessing pickups
# 2  Academy of Raya Lucaria  Vanilla major key item locations
# 3  Academy of Raya Lucaria  Vanilla major key item locations
# 4  Academy of Raya Lucaria                    Merchant shops
#
#                                          Description
# 0  In front of the statue pedestal in Abandoned C...
# 1  On a corpse in front of a tree in the ravine n...
# 2  In a chest unlocked by Discarded Palace Key in...
# 3  On a robed corpse in the Raya Lucaria rooftop ...
# 4  Sold by Isolated Merchant southeast of Main Ac...

# %%
sorted_df.to_excel("output/combined/sorted_data.xlsx", index=False, engine='openpyxl')

# %%
area_keywords = {
    'Limgrave': ['Limgrave', 'Stormhill', 'Knowledge', 'Chapel of Anticipation', 'Stranded Graveyard', 'Beastman', 'Godrick', 'Stormveil', 'Margit', 'Weeping Peninsula', 'Leonine Misbegotten'], 
    'Liurnia of the Lakes': ['Liurnia', 'Academy of Raya Lucaria', 'Makar', 'Bellum', 'Carian', 'Moonlight', 'Red Wolf of Radagon', 'Royal Knight', 'Ruin-Strewn', 'Adula', 'Alecto', 'Moonlight Altar'], 
    'Caelid': ['Redmane', 'Radahn', 'Caelid', 'Dragonbarrow'], 
    'Altus Plateau': ['Altus Plateau', 'Altus Tunnel', 'Capital Outskirts', 'Shaded Castle'], 
    'Mt. Gelmir': ['Mt. Gelmir', 'Volcano Manor', 'Rykard'], 
    'Leyndell, Royal Capital': ['Royal Capital', 'Leyndell', 'Subterranean Shunning-Grounds', 'Divine Tower of East Altus', 'Divine Tower of West Altus', 'the Omen'],
    'Mountaintops of the Giants': ['Mountaintops', 'Niall', 'Sol', 'Fire Giant', 'Flame Peak', 'Forbidden'],
    'Consecrated Snowfield': ['Consecrated Snowfield'],
    "Miquella's Haligtree": ['Haligtree', 'Malenia'],
    'Crumbling Farum Azula': ['Farum Azula', 'Dragon Temple', 'Godskin Duo', 'Maliketh'],
    'Leyndell, Ashen Capital': ['Ashen'],
    'Underground': ['Underground', 'Siofra', 'Ancestor Spirit', 'Nokron', 'Regal', 'Valiant Gargoyles', 'Mimic Tear', 'Lake of Rot', 'Astel, Naturalborn', 'Deeproot Depths', 'Ainsel', 'Nokstella', 'Dragonkin'],
    'Mohgwyn Dynasty Mausoleum': ['Lord of Blood', 'Mohgwyn'],
    'Roundtable': ['Roundtable'],
    'Gravesite Plain': ['Gravesite Plain', 'Belurat', 'Castle Ensis', "Dragon's Pit", 'Western Nameless', 'Dancing Lion', 'Ellac'],
    'Scadu Altus': ['Scadu Altus', 'Shadow Keep', 'Specimen Storehouse', 'Scaduview', 'Scadutree Base', 'Fort of Reprimand', 'Northern Nameless', 'Birthing', 'Rauh Base'],
    'Hinterlands': ['Hinterlands', 'Manus Metyr'],
    'Cerulean Coast': ['Cerulean Coast', 'Southern Nameless', 'Stone Coffin Fissure'],
    'Jagged Peak': ['Jagged Peak', 'Lamenter'],
    'Abyssal Woods': ['Abyssal Woods', 'Eastern Nameless', 'Darklight', 'Midra' ],
    'Ancient Ruins of Rauh': ['Ancient Ruins of Rauh', 'Bud'],
    'Enir-Ilim': ['Enir-Ilim', 'Consort'],
    'Stone Platform': ['Stone Platform']
}

output_dir = 'output/'

# %%
for key, keywords in area_keywords.items():
    # Iterate over the unique values in the "Area" column and check if they contain any keywords
    areas_to_keep = [area for area in sorted_df["Area"].unique() if any(keyword in area for keyword in keywords)]

    area_keywords[key] = areas_to_keep
    
# print(area_keywords)

for key, areas_to_keep in area_keywords.items():    
    # Filter the sorted_df DataFrame based on the areas_to_keep list
    filtered_df = sorted_df[sorted_df["Area"].isin(areas_to_keep)]
    # print(filtered_df.head())
    
    # print(key)
    filtered_df.to_excel(f"{output_dir}{key}.xlsx", index=False, engine='openpyxl')

    # Drop the filtered_df entries from the original sorted_df
    sorted_df = sorted_df.drop(filtered_df.index)

# Print the remaining DataFrame
print(f"\nShould be empty:")
print(sorted_df)
# Out:
# Should be empty:
# Empty DataFrame
# Columns: [Area, Type, Description]
# Index: []

# %%
# Combine into one spreadsheet but separate sheets:
combined_output = f"ALL_Combined"
merged_output = f'ALL_MERGED'

# output_files = [f"{output_dir}{file}" for file in os.listdir(output_dir) if file.endswith('.xlsx') and combined_output not in file and merged_output not in file]
# print(f"All output files: {output_files}")

combined_output = f"{output_dir}{combined_output}.xlsx"
merged_output = f'{output_dir}{merged_output}.xlsx'


with pd.ExcelWriter(combined_output , mode='a', if_sheet_exists='replace') as writer:
    # for file in output_files:    
    for key, _ in area_keywords.items():                     
        # if file.endswith('.xls') or file.endswith('.xlsx'):
        file = f"{output_dir}{key}.xlsx"
        cur_sheet = os.path.splitext(os.path.basename(file))[0]
        print(f"Current sheet is: {cur_sheet}")
        df = pd.read_excel(file)
        df.to_excel(writer, sheet_name=cur_sheet)
# Out:
# Current sheet is: Limgrave
# Current sheet is: Liurnia of the Lakes
# Current sheet is: Caelid
# Current sheet is: Altus Plateau
# Current sheet is: Mt. Gelmir
# Current sheet is: Leyndell, Royal Capital
# Current sheet is: Mountaintops of the Giants
# Current sheet is: Consecrated Snowfield
# Current sheet is: Miquella's Haligtree
# Current sheet is: Crumbling Farum Azula
# Current sheet is: Leyndell, Ashen Capital
# Current sheet is: Underground
# Current sheet is: Mohgwyn Dynasty Mausoleum
# Current sheet is: Roundtable
# Current sheet is: Gravesite Plain
# Current sheet is: Scadu Altus
# Current sheet is: Hinterlands
# Current sheet is: Cerulean Coast
# Current sheet is: Jagged Peak
# Current sheet is: Abyssal Woods
# Current sheet is: Ancient Ruins of Rauh
# Current sheet is: Enir-Ilim
# Current sheet is: Stone Platform

# %%
# Combine into one SHEET on a single spreadsheet
df = pd.read_excel(f"{combined_output}", sheet_name=None, index_col=None)
print(f"{df}")
cdf = pd.concat(df.values(), ignore_index=True)

print(cdf)

# with pd.ExcelWriter(dir_output , mode='a', if_sheet_exists='replace') as writer:
    
#     cdf.to_excel(writer, sheet_name=f"ALL_TOGETHER")
# openpyxl, xlsxwriter
cdf.to_excel(merged_output, engine='openpyxl', sheet_name='Merged', header=True, index=False)
# Out:
# {'Sheet1': Empty DataFrame
# Columns: []
# Index: [], 'Limgrave':     Unnamed: 0                       Area                              Type  \
# 0            0                   Limgrave  Vanilla major key item locations
# 1            1                   Limgrave                    Merchant shops
# 2            2                   Limgrave                    Merchant shops
# 3            3                   Limgrave                    Merchant shops
# 4            4                   Limgrave                    Merchant shops
# 5            5  Limgrave - Murkwater Cave                    Merchant shops
# 6            6                  Stormhill                      Major bosses
# 7            7           Stormveil Castle  Vanilla major key item locations
# 8            8           Stormveil Castle                      Major bosses
# 9            9          Weeping Peninsula                    Merchant shops
# 10          10          Weeping Peninsula                      Major bosses
# 11          11          Weeping Peninsula                    Merchant shops
#
#                                           Description
# 0   In a chest at the top of a tower in Fort Haigh...
# 1   Sold by the Nomadic Merchant in front of Coast...
# 2                 Sold by Kale at the Church of Elleh
# 3   Sold by the Nomadic Merchant between Saintsbri...
# 4   Sold by the Nomadic Merchant in the Mistwood a...
# 5                                     Sold by Patches
# 6   Dropped by Margit the Fell Omen or Morgott the...
# 7   In the dark room before the Rusty Key door, gu...
# 8   Dropped by Godrick the Grafted. Replaces Godri...
# 9   Sold by the Nomadic Merchant at Castle Morne R...
# 10  Dropped by Leonine Misbegotten south of Castle...
# 11  Sold by the Isolated Merchant at the Isolated ...  , 'Liurnia of the Lakes':     Unnamed: 0                        Area                              Type  \
# 0            0     Academy of Raya Lucaria  Vanilla major key item locations
# 1            1     Academy of Raya Lucaria  Vanilla major key item locations
# 2            2     Academy of Raya Lucaria                    Merchant shops
# 3            3     Academy of Raya Lucaria                      Major bosses
# 4            4     Academy of Raya Lucaria                      Major bosses
# 5            5              Bellum Highway                    Merchant shops
# 6            6     Divine Tower of Liurnia  Vanilla major key item locations
# 7            7                     Liurnia  Vanilla major key item locations
# 8            8                     Liurnia  Vanilla major key item locations
# 9            9                     Liurnia                      Major bosses
# 10          10                     Liurnia  Vanilla major key item locations
# 11          11                     Liurnia                    Merchant shops
# 12          12                     Liurnia                    Merchant shops
# 13          13  Liurnia Behind Caria Manor                    Merchant shops
# 14          14       Ruin-Strewn Precipice                      Major bosses
#
#                                           Description
# 0   In a chest unlocked by Discarded Palace Key in...
# 1   On a robed corpse in the Raya Lucaria rooftop ...
# 2   Sold by Isolated Merchant southeast of Main Ac...
# 3   Dropped by Red Wolf of Radagon. Replaces Memor...
# 4   Dropped by Rennala. Replaces Great Rune of the...
# 5   Sold by Nomadic Merchant down the cliffside pa...
# 6   At the top of the Divine Tower of Liurnia, acc...
# 7   Guarded by Glintstone Dragon Smarag. Replaces ...
# 8   Given by Albus the Albinauric in Village of th...
# 9   Dropped by Royal Knight Loretta. Replaces Lore...
# 10  In a chest at the topmost of the Belfries. Rep...
# 11                                        Sold by Iji
# 12  Sold by the Nomadic Merchant by the Liurnia La...
# 13  Sold by Pidia. He can be found by dropping bac...
# 14  Dropped by Magma Wyrm Makar. Replaces Magma Wy...  , 'Caelid':    Unnamed: 0          Area                              Type  \
# 0           0        Caelid  Vanilla major key item locations
# 1           1        Caelid                    Merchant shops
# 2           2        Caelid                    Merchant shops
# 3           3        Caelid                      Major bosses
# 4           4  Dragonbarrow  Vanilla major key item locations
# 5           5  Dragonbarrow                    Merchant shops
#
#                                          Description
# 0  In a chest hidden behind a magical barrier in ...
# 1  Sold by the Nomadic Merchant between Astray fr...
# 2  Sold by the Nomadic Merchant southwest of sout...
# 3  Dropped by Starscourge Radahn. Replaces Radahn...
# 4  In a chest up the first ladder at Fort Faroth....
# 5  Sold by the Isolated Merchant at Isolated Merc...  , 'Altus Plateau':    Unnamed: 0               Area            Type  \
# 0           0      Altus Plateau  Merchant shops
# 1           1      Altus Plateau    Major bosses
# 2           2  Capital Outskirts  Merchant shops
#
#                                          Description
# 0  Sold by the Nomadic Merchant at the southern e...
# 1  Dropped by Elemer of the Briar. Replaces Marai...
# 2  Sold by the Hermit Merchant at the Hermit's Me...  , 'Mt. Gelmir':    Unnamed: 0           Area                              Type  \
# 0           0     Mt. Gelmir                    Merchant shops
# 1           1  Volcano Manor                      Major bosses
# 2           2  Volcano Manor                      Major bosses
# 3           3  Volcano Manor  Vanilla major key item locations
#
#                                          Description
# 0  Sold by the Nomadic Merchant in the long ladde...
# 1  Dropped by Rykard. Replaces Rykard's Great Run...
# 2  Dropped by Godskin Noble. Replaces Godskin Sti...
# 3  Given by Tanith upon joining Volcano Manor, or...  , 'Leyndell, Royal Capital':    Unnamed: 0                           Area  \
# 0           0                 Ashen Leyndell
# 1           1                       Leyndell
# 2           2                       Leyndell
# 3           3                       Leyndell
# 4           4  Subterranean Shunning-Grounds
#
#                                Type  \
# 0                      Major bosses
# 1  Vanilla major key item locations
# 2                      Major bosses
# 3                      Major bosses
# 4                      Major bosses
#
#                                          Description
# 0  Dropped by Hoarah Loux. Replaces Remembrance o...
# 1  Given by Melina after defeating Morgott. Repla...
# 2  Dropped by Morgott the Omen King. Replaces Mor...
# 3  Dropped by Godfrey, First Elden Lord, in the E...
# 4  Dropped by Mohg the Omen. Replaces Bloodflame ...  , 'Mountaintops of the Giants':    Unnamed: 0                        Area                              Type  \
# 0           0                  Flame Peak                      Major bosses
# 1           1  Mountaintops of the Giants                      Major bosses
# 2           2  Mountaintops of the Giants  Vanilla major key item locations
# 3           3  Mountaintops of the Giants                    Merchant shops
#
#                                          Description
# 0  Dropped by Fire Giant. Replaces Remembrance of...
# 1  Dropped by Commander Niall in Castle Sol. Repl...
# 2  Atop a tower after defeating Commander Niall. ...
# 3  Sold by the Hermit Merchant along a cliffside ...  , 'Consecrated Snowfield': Empty DataFrame
# Columns: [Unnamed: 0, Area, Type, Description]
# Index: [], "Miquella's Haligtree":    Unnamed: 0       Area          Type  \
# 0           0  Haligtree  Major bosses
# 1           1  Haligtree  Major bosses
#
#                                          Description
# 0  Dropped by Malenia. Replaces Malenia's Great R...
# 1  Dropped by Loretta, Knight of the Haligtree. R...  , 'Crumbling Farum Azula':    Unnamed: 0         Area          Type  \
# 0           0  Farum Azula  Major bosses
# 1           1  Farum Azula  Major bosses
# 2           2  Farum Azula  Major bosses
#
#                                          Description
# 0  Dropped by Maliketh, the Black Blade. Replaces...
# 1  Dropped by Dragonlord Placidusax. Replaces Rem...
# 2  Dropped by Godskin Duo. Replaces Smithing-Ston...  , 'Leyndell, Ashen Capital': Empty DataFrame
# Columns: [Unnamed: 0, Area, Type, Description]
# Index: [], 'Underground':    Unnamed: 0                     Area            Type  \
# 0           0             Ainsel River    Major bosses
# 1           1  Ainsel River Downstream  Merchant shops
# 2           2  Ainsel River Downstream    Major bosses
# 3           3     Nokron, Eternal City    Major bosses
# 4           4     Nokron, Eternal City    Major bosses
# 5           5     Nokron, Eternal City    Major bosses
# 6           6             Siofra River    Major bosses
# 7           7             Siofra River  Merchant shops
#
#                                          Description
# 0  Dropped by Astel, Naturalborn of the Void. Rep...
# 1  Sold by the Hermit Merchant in the alcove past...
# 2  Dropped by Dragonkin Soldier of Nokstella. Rep...
# 3  Dropped by Regal Ancestor Spirit. Replaces Rem...
# 4  Dropped by Mimic Tear. Replaces Silver Tear Ma...
# 5  Dropped by Valiant Gargoyles after Siofra Aque...
# 6  Dropped by Ancestor Spirit. Replaces Ancestral...
# 7  Sold by the Abandoned Merchant overlooking the...  , 'Mohgwyn Dynasty Mausoleum':    Unnamed: 0     Area            Type  \
# 0           0  Mohgwyn  Merchant shops
# 1           1  Mohgwyn    Major bosses
#
#                                          Description
# 0  Sold by the Imprisoned Merchant in the cave wi...
# 1  Dropped by Mohg, Lord of Blood. Replaces Mohg'...  , 'Roundtable':    Unnamed: 0             Area            Type                Description
# 0           0  Roundtable Hold  Merchant shops  Sold by Twin Maiden Husks, 'Gravesite Plain':     Unnamed: 0             Area                              Type  \
# 0            0          Belurat     Shadow Realm Blessing pickups
# 1            1          Belurat     Shadow Realm Blessing pickups
# 2            2          Belurat     Shadow Realm Blessing pickups
# 3            3          Belurat  Vanilla major key item locations
# 4            4          Belurat                      Major bosses
# 5            5          Belurat     Shadow Realm Blessing pickups
# 6            6     Castle Ensis                      Major bosses
# 7            7     Castle Ensis  Vanilla major key item locations
# 8            8     Castle Ensis     Shadow Realm Blessing pickups
# 9            9      Ellac River     Shadow Realm Blessing pickups
# 10          10  Gravesite Plain     Shadow Realm Blessing pickups
# 11          11  Gravesite Plain     Shadow Realm Blessing pickups
# 12          12  Gravesite Plain     Shadow Realm Blessing pickups
# 13          13  Gravesite Plain     Shadow Realm Blessing pickups
# 14          14  Gravesite Plain     Shadow Realm Blessing pickups
# 15          15  Gravesite Plain     Shadow Realm Blessing pickups
# 16          16  Gravesite Plain     Shadow Realm Blessing pickups
# 17          17  Gravesite Plain     Shadow Realm Blessing pickups
# 18          18  Gravesite Plain                    Merchant shops
#
#                                           Description
# 0   By the Miquella's Cross hidden in Belurat, acc...
# 1   On a large withered corpse facing the large tr...
# 2   On a large withered corpse up the elevator fro...
# 3   On a corpse accessible from the bridge above t...
# 4   Dropped by Divine Beast Dancing Lion. Replaces...
# 5   On the large withered statue in the scorpion r...
# 6   Dropped by Rellana, Twin Moon Knight. Replaces...
# 7   In a chest in the tower on the castle's southe...
# 8   By Miquella's Cross at the Castle Ensis Checkp...
# 9   On a large withered corpse in the cave section...
# 10  By Miquella's Cross at the Pillar Path Cross g...
# 11  In front of the beheaded Marika statue in the ...
# 12  In front of a beheaded Marika statue in the Ca...
# 13  By Miquella's Cross at the Three-Path Cross. R...
# 14  By Miquella's Cross at Main Gate Cross. Replac...
# 15  On a large withered corpse on the cliffside ea...
# 16  On a large withered corpse on the east cliffsi...
# 17  On a large withered corpse by the lake northea...
# 18                                      Sold by Moore  , 'Scadu Altus':     Unnamed: 0                           Area  \
# 0            0        Finger Birthing Grounds
# 1            1              Lower Scadu Altus
# 2            2              Lower Scadu Altus
# 3            3              Lower Scadu Altus
# 4            4                      Rauh Base
# 5            5                    Scadu Altus
# 6            6                    Scadu Altus
# 7            7                    Scadu Altus
# 8            8                    Scadu Altus
# 9            9                    Scadu Altus
# 10          10                    Scadu Altus
# 11          11                    Scadu Altus
# 12          12                    Scadu Altus
# 13          13                    Scadu Altus
# 14          14                    Scadu Altus
# 15          15                    Scadu Altus
# 16          16                 Scadutree Base
# 17          17                      Scaduview
# 18          18                      Scaduview
# 19          19                      Scaduview
# 20          20                    Shadow Keep
# 21          21  Shadow Keep - Church District
# 22          22            Specimen Storehouse
# 23          23            Specimen Storehouse
# 24          24            Specimen Storehouse
# 25          25            Specimen Storehouse
# 26          26            Specimen Storehouse
#
#                                 Type  \
# 0                       Major bosses
# 1      Shadow Realm Blessing pickups
# 2      Shadow Realm Blessing pickups
# 3      Shadow Realm Blessing pickups
# 4      Shadow Realm Blessing pickups
# 5   Vanilla major key item locations
# 6      Shadow Realm Blessing pickups
# 7   Vanilla major key item locations
# 8      Shadow Realm Blessing pickups
# 9      Shadow Realm Blessing pickups
# 10     Shadow Realm Blessing pickups
# 11     Shadow Realm Blessing pickups
# 12     Shadow Realm Blessing pickups
# 13     Shadow Realm Blessing pickups
# 14     Shadow Realm Blessing pickups
# 15     Shadow Realm Blessing pickups
# 16                      Major bosses
# 17                      Major bosses
# 18     Shadow Realm Blessing pickups
# 19     Shadow Realm Blessing pickups
# 20                      Major bosses
# 21     Shadow Realm Blessing pickups
# 22                      Major bosses
# 23     Shadow Realm Blessing pickups
# 24     Shadow Realm Blessing pickups
# 25     Shadow Realm Blessing pickups
# 26     Shadow Realm Blessing pickups
#
#                                           Description
# 0   Dropped by Metyr, Mother of Fingers. Replaces ...
# 1   On a large withered corpse west of the upper V...
# 2   On the large withered corpse in southeast Cast...
# 3   At the bottom of the waterfall below the Reclu...
# 4   On a corpse on a walkway overlooking the block...
# 5   In front of the tree to the north of Bonny Vil...
# 6   On a large withered corpse at the far north en...
# 7   Given by Count Ymir when you first meet him in...
# 8   By Miquella's Cross at the Highroad Cross grac...
# 9   By Miquella's Cross at the Moorth Ruins grace....
# 10  In front of a beheaded Marika statue in the en...
# 11  By Miquella's Cross at the Scaduview Cross gra...
# 12  On the large withered corpse along the cliffsi...
# 13  In front of the beheaded Marika statue in the ...
# 14  In front of the beheaded Marika statue north o...
# 15  On a corpse in front of the headless Marika st...
# 16  Dropped by Scadutree Avatar. Replaces Remembra...
# 17  Dropped by Commander Gaius. Replaces Remembran...
# 18  In front of the beheaded Marika statue east of...
# 19  In front of the Scadutree Chalice. Replaces Sc...
# 20  Dropped by Golden Hippopotamus. Replaces Aspec...
# 21  On the left hand of the giant Marika statue in...
# 22  Dropped by Messmer the Impaler. Replaces Remem...
# 23  On top of a hanging beast which can be jumped ...
# 24  In front of a beheaded Marika statue right bef...
# 25  By Miquella's Cross at the Storehouse Fourth F...
# 26  On top of the beast in front of the first floo...  , 'Hinterlands': Empty DataFrame
# Columns: [Unnamed: 0, Area, Type, Description]
# Index: [], 'Cerulean Coast':    Unnamed: 0                  Area                           Type  \
# 0           0        Cerulean Coast  Shadow Realm Blessing pickups
# 1           1        Cerulean Coast  Shadow Realm Blessing pickups
# 2           2  Stone Coffin Fissure                   Major bosses
# 3           3  Stone Coffin Fissure  Shadow Realm Blessing pickups
#
#                                          Description
# 0  On a corpse guarded by an enemy in a small cav...
# 1  By Miquella's Cross at the Cerulean Coast Cros...
# 2  Dropped by Putrescent Knight. Replaces Remembr...
# 3  By Miquella's Cross at the Fissure Cross grace...  , 'Jagged Peak':    Unnamed: 0         Area                           Type  \
# 0           0  Jagged Peak                   Major bosses
# 1           1  Jagged Peak  Shadow Realm Blessing pickups
#
#                                          Description
# 0  Dropped by Bayle the Dread. Replaces Heart of ...
# 1  On a corpse under where the boulder starts rol...  , 'Abyssal Woods':    Unnamed: 0           Area                           Type  \
# 0           0  Abyssal Woods  Shadow Realm Blessing pickups
# 1           1  Abyssal Woods  Shadow Realm Blessing pickups
# 2           2  Midra's Manse                   Major bosses
# 3           3  Midra's Manse  Shadow Realm Blessing pickups
#
#                                          Description
# 0  In front of the statue pedestal in Abandoned C...
# 1  On a corpse in front of a tree in the ravine n...
# 2  Dropped by Midra, Lord of Frenzied Flame. Repl...
# 3  On a corpse on a chandelier, accessed by jumpi...  , 'Ancient Ruins of Rauh':    Unnamed: 0                   Area                           Type  \
# 0           0  Ancient Ruins of Rauh  Shadow Realm Blessing pickups
# 1           1  Ancient Ruins of Rauh                   Major bosses
# 2           2  Ancient Ruins of Rauh  Shadow Realm Blessing pickups
# 3           3  Ancient Ruins of Rauh  Shadow Realm Blessing pickups
#
#                                          Description
# 0  On a large withered corpse in the gazebo in th...
# 1  Dropped by Romina, Saint of the Bud. Replaces ...
# 2  By Miquella's Cross at the East Ruins grace. R...
# 3  In front of the northwest wall monument on the...  , 'Enir-Ilim':    Unnamed: 0       Area                           Type  \
# 0           0  Enir-Ilim  Shadow Realm Blessing pickups
# 1           1  Enir-Ilim  Shadow Realm Blessing pickups
# 2           2  Enir-Ilim                   Major bosses
# 3           3  Enir-Ilim  Shadow Realm Blessing pickups
# 4           4  Enir-Ilim  Shadow Realm Blessing pickups
# 5           5  Enir-Ilim  Shadow Realm Blessing pickups
# 6           6  Enir-Ilim  Shadow Realm Blessing pickups
#
#                                          Description
# 0  On a large withered corpse in a shrine after t...
# 1  In front of a statue along the dropdown to Eup...
# 2  Dropped by Promised Consort Radahn. Replaces R...
# 3  On a large withered corpse in front of several...
# 4  In front of the altar in the Cleansing Chamber...
# 5  In front of an altar in the top room of a side...
# 6  By Miquella's Cross at the Spiral Rise grace. ...  , 'Stone Platform':    Unnamed: 0            Area          Type  \
# 0           0  Stone Platform  Major bosses
#
#                                          Description
# 0  Dropped by Elden Beast. Replaces Elden Remembr...  }
#     Unnamed: 0            Area                              Type  \
# 0            0        Limgrave  Vanilla major key item locations
# 1            1        Limgrave                    Merchant shops
# 2            2        Limgrave                    Merchant shops
# 3            3        Limgrave                    Merchant shops
# 4            4        Limgrave                    Merchant shops
# ..         ...             ...                               ...
# 128          3       Enir-Ilim     Shadow Realm Blessing pickups
# 129          4       Enir-Ilim     Shadow Realm Blessing pickups
# 130          5       Enir-Ilim     Shadow Realm Blessing pickups
# 131          6       Enir-Ilim     Shadow Realm Blessing pickups
# 132          0  Stone Platform                      Major bosses
#
#                                            Description
# 0    In a chest at the top of a tower in Fort Haigh...
# 1    Sold by the Nomadic Merchant in front of Coast...
# 2                  Sold by Kale at the Church of Elleh
# 3    Sold by the Nomadic Merchant between Saintsbri...
# 4    Sold by the Nomadic Merchant in the Mistwood a...
# ..                                                 ...
# 128  On a large withered corpse in front of several...
# 129  In front of the altar in the Cleansing Chamber...
# 130  In front of an altar in the top room of a side...
# 131  By Miquella's Cross at the Spiral Rise grace. ...
# 132  Dropped by Elden Beast. Replaces Elden Remembr...
#
# [133 rows x 4 columns]
